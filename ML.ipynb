# %%
import pandas as pd

# %%
df=pd.read_csv('https://raw.githubusercontent.com/shsarv/Machine-Learning-Projects/main/Diabetes%20Prediction%20%5BEND%202%20END%5D/dataset/kaggle_diabetes.csv',na_values=['?',' ?','? ','na','-',0])

# %%
df.loc[df['Pregnancies'] == 'NaN', 'Pregnancies'] = df['Pregnancies'].fillna(0,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18172\2704732857.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.loc[df['Pregnancies'] == 'NaN', 'Pregnancies'] = df['Pregnancies'].fillna(0,inplace=True)

# %%
df.loc[df['Outcome'] == 'NaN', 'Outcome'] = df['Outcome'].fillna(0,inplace=True)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_18172\2717572992.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df.loc[df['Outcome'] == 'NaN', 'Outcome'] = df['Outcome'].fillna(0,inplace=True)

# %%
df
# Out:
#       Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0             2.0    138.0           62.0           35.0      NaN  33.6
# 1             0.0     84.0           82.0           31.0    125.0  38.2
# 2             0.0    145.0            NaN            NaN      NaN  44.2
# 3             0.0    135.0           68.0           42.0    250.0  42.3
# 4             1.0    139.0           62.0           41.0    480.0  40.7
# ...           ...      ...            ...            ...      ...   ...
# 1995          2.0     75.0           64.0           24.0     55.0  29.7
# 1996          8.0    179.0           72.0           42.0    130.0  32.7
# 1997          6.0     85.0           78.0            NaN      NaN  31.2
# 1998          0.0    129.0          110.0           46.0    130.0  67.1
# 1999          2.0     81.0           72.0           15.0     76.0  30.1
#
#       DiabetesPedigreeFunction  Age  Outcome
# 0                        0.127   47      1.0
# ...

# %%
from sklearn.impute import KNNImputer

# %%
kn= KNNImputer(n_neighbors=3)

# %%
x_ar=kn.fit_transform(x)

# %%
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
y=df['Outcome']
x=df.drop('Outcome',axis=1)

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.25,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dr=DecisionTreeClassifier()

# %%
dr.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
print(dr.score(x_test,y_test))
print(dr.score(x_train,y_train))
# Out:
# 0.976
# 1.0

# %%
from sklearn.model_selection import cross_val_score

# %%
cross_val_score(dr,x_test,y_test,cv=5)
# Out:
# array([0.75, 0.85, 0.86, 0.78, 0.76])

# %%
from sklearn.linear_model import LogisticRegression

# %%
lgr = LogisticRegression()

# %%
lgr.fit(x_train,y_train)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
print("test Result", lgr.score(x_test,y_test))
print("train Result", lgr.score(x_train,y_train))
# Out:
# test Result 0.794
# train Result 0.7773333333333333

# %%
from sklearn.model_selection import GridSearchCV

# %%
param_grid={'C':[0.1,0.01,1,10,100,10000],                            # Regularization parameter
            'penalty':['l2','l1','elasticnet'],                         # penalty
            'solver':['liblinear']}

# %%
log_reg= LogisticRegression(max_iter=1000)

# %%
grid_search=GridSearchCV(estimator=log_reg,param_grid=param_grid,cv=5,scoring='accuracy')

# %%
grid_search.fit(x_train,y_train)
# Out:
# c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py:540: FitFailedWarning:
# 30 fits failed out of a total of 90.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 30 fits failed with the following error:
# Traceback (most recent call last):
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\model_selection\_validation.py", line 888, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "c:\Users\hp\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py", line 1473, in wrapper
#     return fit_method(estimator, *args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# ...

# %% [markdown]
# #### Logistic Regression Model

# %%
lgr=LogisticRegression(max_iter=1000,C=1,penalty='l1',solver='liblinear')

# %%
lgr.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1, max_iter=1000, penalty='l1', solver='liblinear')

# %%
lgr.score(x_test,y_test)
# Out:
# 0.784

# %%
df['Outcome'].value_counts()
# Out:
# Outcome
# 0.0    1316
# 1.0     684
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix

# %%
y_pred=lgr.predict(x_test)

# %% [markdown]
# ###### TP = 290, FN= 73, FP= 30, TP= 107

# %%
confusion_matrix(y_test,y_pred)
# Out:
# array([[288,  32],
#        [ 76, 104]])

# %% [markdown]
# #### Exporting the model

# %%
import pickle

# %%
with open('model.pickle','wb') as model_file:
    pickle.dump(lgr,model_file)
